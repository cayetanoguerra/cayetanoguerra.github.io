# %% [markdown]
# # U-net
#
# Segmentación semántica
#
# <img src="./misc/u-net-architecture.png" width="75%">

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms, utils
from torchvision.io import read_file, decode_jpeg, decode_png, ImageReadMode
import torchvision.transforms as T
import matplotlib.pyplot as plt
from torchvision.io import read_image

# %%
# DATASET
import os

# read dataset for u-net
class Dataset(Dataset):
    def __init__(self, data_dir, label_dir):
        self.data_dir = data_dir
        self.label_dir = label_dir
        self.files = [os.path.splitext(f)[0] for f in os.listdir(data_dir)]
        self.transform = T.Resize((512, 512))

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        file_name = self.files[idx]
        # read image
        image = read_image(os.path.join(self.data_dir, file_name + ".png"), mode=ImageReadMode.RGB)
        
        # read mask
        mask = read_image(os.path.join(self.label_dir, file_name + ".png"), mode=ImageReadMode.GRAY)
        
        # resize
        image = self.transform(image)
        mask = self.transform(mask)
        
        image = torch.tensor(image, dtype=torch.float32)
        mask = torch.tensor(mask, dtype=torch.float32)
        
        image = image / 255.0
        mask /= 255.0
        mask = torch.round(mask)

        return image, mask
        

        
ds = Dataset("./data/Synthetic/test", "./data/Synthetic/labels")
ds_loader = DataLoader(ds, batch_size=4)

# %%
import torch
import torch.nn as nn

""" Convolutional block:
    It follows a two 3x3 convolutional layer, each followed by a batch normalization and a relu activation.
"""
class conv_block(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.conv1 = nn.Conv2d(in_c, out_c, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(out_c)

        self.conv2 = nn.Conv2d(out_c, out_c, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_c)

        self.relu = nn.ReLU()

    def forward(self, inputs):
        x = self.conv1(inputs)
        x = self.bn1(x)
        x = self.relu(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)

        return x

""" Encoder block:
    It consists of an conv_block followed by a max pooling.
    Here the number of filters doubles and the height and width half after every block.
"""
class encoder_block(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.conv = conv_block(in_c, out_c)
        self.pool = nn.MaxPool2d((2, 2))

    def forward(self, inputs):
        x = self.conv(inputs)
        p = self.pool(x)

        return x, p

""" Decoder block:
    The decoder block begins with a transpose convolution, followed by a concatenation with the skip
    connection from the encoder block. Next comes the conv_block.
    Here the number filters decreases by half and the height and width doubles.
"""
class decoder_block(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.up = nn.ConvTranspose2d(in_c, out_c, kernel_size=2, stride=2, padding=0)
        self.conv = conv_block(out_c+out_c, out_c)

    def forward(self, inputs, skip):
        x = self.up(inputs)
        x = torch.cat([x, skip], axis=1)
        x = self.conv(x)

        return x


class build_unet(nn.Module):
    def __init__(self):
        super().__init__()

        """ Encoder """
        self.e1 = encoder_block(3, 64)
        self.e2 = encoder_block(64, 128)
        self.e3 = encoder_block(128, 256)
        self.e4 = encoder_block(256, 512)

        """ Bottleneck """
        self.b = conv_block(512, 1024)

        """ Decoder """
        self.d1 = decoder_block(1024, 512)
        self.d2 = decoder_block(512, 256)
        self.d3 = decoder_block(256, 128)
        self.d4 = decoder_block(128, 64)

        """ Classifier """
        self.outputs = nn.Conv2d(64, 1, kernel_size=1, padding=0)

    def forward(self, inputs):
        """ Encoder """
        s1, p1 = self.e1(inputs)
        s2, p2 = self.e2(p1)
        s3, p3 = self.e3(p2)
        s4, p4 = self.e4(p3)

        """ Bottleneck """
        b = self.b(p4)

        """ Decoder """
        d1 = self.d1(b, s4)
        d2 = self.d2(d1, s3)
        d3 = self.d3(d2, s2)
        d4 = self.d4(d3, s1)

        """ Classifier """
        outputs = self.outputs(d4)

        return outputs

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

inputs = torch.randn((2, 3, 512, 512)).to(device)
model = build_unet().to(device)
y = model(inputs)
print(y.shape)
# Out:
# torch.Size([2, 1, 512, 512])

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(),
                             lr=1e-3, 
                             weight_decay=1e-5)

# %%
num_epochs = 200

for epoch in range(num_epochs):
    for idx, (images, labels) in enumerate(ds_loader):
        # Forward pass
        outputs = model(images.to(device))
        loss = criterion(outputs, labels.to(device))
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print("Lote:", idx)

    print (f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_17088\1362357891.py:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_17088\1362357891.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mask = torch.tensor(mask, dtype=torch.float32)
# Lote: 0
# Epoch [1/200], Loss: 0.2431
# Lote: 0
# Epoch [2/200], Loss: 0.5874
# Lote: 0
# Epoch [3/200], Loss: 0.1337
# Lote: 0
# Epoch [4/200], Loss: 0.0986
# Lote: 0
# Epoch [5/200], Loss: 0.0583
# Lote: 0
# Epoch [6/200], Loss: 0.0418
# Lote: 0
# Epoch [7/200], Loss: 0.0284
# Lote: 0
# Epoch [8/200], Loss: 0.0222
# Lote: 0
# Epoch [9/200], Loss: 0.0197
# Lote: 0
# Epoch [10/200], Loss: 0.0162
# Lote: 0
# Epoch [11/200], Loss: 0.0133
# Lote: 0
# Epoch [12/200], Loss: 0.0111
# Lote: 0
# Epoch [13/200], Loss: 0.0092
# Lote: 0
# Epoch [14/200], Loss: 0.0082
# Lote: 0
# Epoch [15/200], Loss: 0.0077
# Lote: 0
# Epoch [16/200], Loss: 0.0070
# Lote: 0
# Epoch [17/200], Loss: 0.0060
# Lote: 0
# Epoch [18/200], Loss: 0.0053
# Lote: 0
# Epoch [19/200], Loss: 0.0050
# Lote: 0
# Epoch [20/200], Loss: 0.0046
# Lote: 0
# Epoch [21/200], Loss: 0.0042
# Lote: 0
# Epoch [22/200], Loss: 0.0041
# Lote: 0
# Epoch [23/200], Loss: 0.0040
# Lote: 0
# Epoch [24/200], Loss: 0.0037
# Lote: 0
# Epoch [25/200], Loss: 0.0035
# Lote: 0
# Epoch [26/200], Loss: 0.0033
# Lote: 0
# Epoch [27/200], Loss: 0.0031
# Lote: 0
# Epoch [28/200], Loss: 0.0029
# Lote: 0
# Epoch [29/200], Loss: 0.0028
# Lote: 0
# Epoch [30/200], Loss: 0.0026
# Lote: 0
# Epoch [31/200], Loss: 0.0025
# Lote: 0
# Epoch [32/200], Loss: 0.0024
# Lote: 0
# Epoch [33/200], Loss: 0.0024
# Lote: 0
# Epoch [34/200], Loss: 0.0023
# Lote: 0
# Epoch [35/200], Loss: 0.0023
# Lote: 0
# Epoch [36/200], Loss: 0.0022
# Lote: 0
# Epoch [37/200], Loss: 0.0022
# Lote: 0
# Epoch [38/200], Loss: 0.0021
# Lote: 0
# Epoch [39/200], Loss: 0.0021
# Lote: 0
# Epoch [40/200], Loss: 0.0020
# Lote: 0
# Epoch [41/200], Loss: 0.0020
# Lote: 0
# Epoch [42/200], Loss: 0.0019
# Lote: 0
# Epoch [43/200], Loss: 0.0019
# Lote: 0
# Epoch [44/200], Loss: 0.0018
# Lote: 0
# Epoch [45/200], Loss: 0.0018
# Lote: 0
# Epoch [46/200], Loss: 0.0018
# Lote: 0
# Epoch [47/200], Loss: 0.0018
# Lote: 0
# Epoch [48/200], Loss: 0.0017
# Lote: 0
# Epoch [49/200], Loss: 0.0017
# Lote: 0
# Epoch [50/200], Loss: 0.0017
# Lote: 0
# Epoch [51/200], Loss: 0.0017
# Lote: 0
# Epoch [52/200], Loss: 0.0016
# Lote: 0
# Epoch [53/200], Loss: 0.0016
# Lote: 0
# Epoch [54/200], Loss: 0.0016
# Lote: 0
# Epoch [55/200], Loss: 0.0016
# Lote: 0
# Epoch [56/200], Loss: 0.0015
# Lote: 0
# Epoch [57/200], Loss: 0.0015
# Lote: 0
# Epoch [58/200], Loss: 0.0015
# Lote: 0
# Epoch [59/200], Loss: 0.0015
# Lote: 0
# Epoch [60/200], Loss: 0.0015
# Lote: 0
# Epoch [61/200], Loss: 0.0015
# Lote: 0
# Epoch [62/200], Loss: 0.0014
# Lote: 0
# Epoch [63/200], Loss: 0.0014
# Lote: 0
# Epoch [64/200], Loss: 0.0014
# Lote: 0
# Epoch [65/200], Loss: 0.0014
# Lote: 0
# Epoch [66/200], Loss: 0.0014
# Lote: 0
# Epoch [67/200], Loss: 0.0014
# Lote: 0
# Epoch [68/200], Loss: 0.0014
# Lote: 0
# Epoch [69/200], Loss: 0.0014
# Lote: 0
# Epoch [70/200], Loss: 0.0015
# Lote: 0
# Epoch [71/200], Loss: 0.0014
# Lote: 0
# Epoch [72/200], Loss: 0.0013
# Lote: 0
# Epoch [73/200], Loss: 0.0014
# Lote: 0
# Epoch [74/200], Loss: 0.0013
# Lote: 0
# Epoch [75/200], Loss: 0.0013
# Lote: 0
# Epoch [76/200], Loss: 0.0013
# Lote: 0
# Epoch [77/200], Loss: 0.0013
# Lote: 0
# Epoch [78/200], Loss: 0.0013
# Lote: 0
# Epoch [79/200], Loss: 0.0013
# Lote: 0
# Epoch [80/200], Loss: 0.0013
# Lote: 0
# Epoch [81/200], Loss: 0.0013
# Lote: 0
# Epoch [82/200], Loss: 0.0012
# Lote: 0
# Epoch [83/200], Loss: 0.0012
# Lote: 0
# Epoch [84/200], Loss: 0.0012
# Lote: 0
# Epoch [85/200], Loss: 0.0012
# Lote: 0
# Epoch [86/200], Loss: 0.0012
# Lote: 0
# Epoch [87/200], Loss: 0.0012
# Lote: 0
# Epoch [88/200], Loss: 0.0012
# Lote: 0
# Epoch [89/200], Loss: 0.0012
# Lote: 0
# Epoch [90/200], Loss: 0.0012
# Lote: 0
# Epoch [91/200], Loss: 0.0012
# Lote: 0
# Epoch [92/200], Loss: 0.0012
# Lote: 0
# Epoch [93/200], Loss: 0.0011
# Lote: 0
# Epoch [94/200], Loss: 0.0011
# Lote: 0
# Epoch [95/200], Loss: 0.0011
# Lote: 0
# Epoch [96/200], Loss: 0.0011
# Lote: 0
# Epoch [97/200], Loss: 0.0011
# Lote: 0
# Epoch [98/200], Loss: 0.0011
# Lote: 0
# Epoch [99/200], Loss: 0.0011
# Lote: 0
# Epoch [100/200], Loss: 0.0011
# Lote: 0
# Epoch [101/200], Loss: 0.0011
# Lote: 0
# Epoch [102/200], Loss: 0.0011
# Lote: 0
# Epoch [103/200], Loss: 0.0011
# Lote: 0
# Epoch [104/200], Loss: 0.0011
# Lote: 0
# Epoch [105/200], Loss: 0.0011
# Lote: 0
# Epoch [106/200], Loss: 0.0012
# Lote: 0
# Epoch [107/200], Loss: 0.0011
# Lote: 0
# Epoch [108/200], Loss: 0.0011
# Lote: 0
# Epoch [109/200], Loss: 0.0011
# Lote: 0
# Epoch [110/200], Loss: 0.0011
# Lote: 0
# Epoch [111/200], Loss: 0.0011
# Lote: 0
# Epoch [112/200], Loss: 0.0011
# Lote: 0
# Epoch [113/200], Loss: 0.0011
# Lote: 0
# Epoch [114/200], Loss: 0.0011
# Lote: 0
# Epoch [115/200], Loss: 0.0011
# Lote: 0
# Epoch [116/200], Loss: 0.0010
# Lote: 0
# Epoch [117/200], Loss: 0.0011
# Lote: 0
# Epoch [118/200], Loss: 0.0010
# Lote: 0
# Epoch [119/200], Loss: 0.0010
# Lote: 0
# Epoch [120/200], Loss: 0.0010
# Lote: 0
# Epoch [121/200], Loss: 0.0010
# Lote: 0
# Epoch [122/200], Loss: 0.0010
# Lote: 0
# Epoch [123/200], Loss: 0.0010
# Lote: 0
# Epoch [124/200], Loss: 0.0010
# Lote: 0
# Epoch [125/200], Loss: 0.0010
# Lote: 0
# Epoch [126/200], Loss: 0.0010
# Lote: 0
# Epoch [127/200], Loss: 0.0010
# Lote: 0
# Epoch [128/200], Loss: 0.0010
# Lote: 0
# Epoch [129/200], Loss: 0.0010
# Lote: 0
# Epoch [130/200], Loss: 0.0010
# Lote: 0
# Epoch [131/200], Loss: 0.0010
# Lote: 0
# Epoch [132/200], Loss: 0.0010
# Lote: 0
# Epoch [133/200], Loss: 0.0009
# Lote: 0
# Epoch [134/200], Loss: 0.0009
# Lote: 0
# Epoch [135/200], Loss: 0.0009
# Lote: 0
# Epoch [136/200], Loss: 0.0009
# Lote: 0
# Epoch [137/200], Loss: 0.0009
# Lote: 0
# Epoch [138/200], Loss: 0.0009
# Lote: 0
# Epoch [139/200], Loss: 0.0009
# Lote: 0
# Epoch [140/200], Loss: 0.0009
# Lote: 0
# Epoch [141/200], Loss: 0.0009
# Lote: 0
# Epoch [142/200], Loss: 0.0009
# Lote: 0
# Epoch [143/200], Loss: 0.0009
# Lote: 0
# Epoch [144/200], Loss: 0.0009
# Lote: 0
# Epoch [145/200], Loss: 0.0009
# Lote: 0
# Epoch [146/200], Loss: 0.0009
# Lote: 0
# Epoch [147/200], Loss: 0.0009
# Lote: 0
# Epoch [148/200], Loss: 0.0009
# Lote: 0
# Epoch [149/200], Loss: 0.0009
# Lote: 0
# Epoch [150/200], Loss: 0.0009
# Lote: 0
# Epoch [151/200], Loss: 0.0009
# Lote: 0
# Epoch [152/200], Loss: 0.0009
# Lote: 0
# Epoch [153/200], Loss: 0.0009
# Lote: 0
# Epoch [154/200], Loss: 0.0009
# Lote: 0
# Epoch [155/200], Loss: 0.0009
# Lote: 0
# Epoch [156/200], Loss: 0.0009
# Lote: 0
# Epoch [157/200], Loss: 0.0009
# Lote: 0
# Epoch [158/200], Loss: 0.0009
# Lote: 0
# Epoch [159/200], Loss: 0.0009
# Lote: 0
# Epoch [160/200], Loss: 0.0009
# Lote: 0
# Epoch [161/200], Loss: 0.0009
# Lote: 0
# Epoch [162/200], Loss: 0.0009
# Lote: 0
# Epoch [163/200], Loss: 0.0008
# Lote: 0
# Epoch [164/200], Loss: 0.0008
# Lote: 0
# Epoch [165/200], Loss: 0.0008
# Lote: 0
# Epoch [166/200], Loss: 0.0008
# Lote: 0
# Epoch [167/200], Loss: 0.0008
# Lote: 0
# Epoch [168/200], Loss: 0.0008
# Lote: 0
# Epoch [169/200], Loss: 0.0008
# Lote: 0
# Epoch [170/200], Loss: 0.0008
# Lote: 0
# Epoch [171/200], Loss: 0.0008
# Lote: 0
# Epoch [172/200], Loss: 0.0008
# Lote: 0
# Epoch [173/200], Loss: 0.0008
# Lote: 0
# Epoch [174/200], Loss: 0.0008
# Lote: 0
# Epoch [175/200], Loss: 0.0008
# Lote: 0
# Epoch [176/200], Loss: 0.0009
# Lote: 0
# Epoch [177/200], Loss: 0.0010
# Lote: 0
# Epoch [178/200], Loss: 0.0008
# Lote: 0
# Epoch [179/200], Loss: 0.0009
# Lote: 0
# Epoch [180/200], Loss: 0.0009
# Lote: 0
# Epoch [181/200], Loss: 0.0008
# Lote: 0
# Epoch [182/200], Loss: 0.0008
# Lote: 0
# Epoch [183/200], Loss: 0.0008
# Lote: 0
# Epoch [184/200], Loss: 0.0008
# Lote: 0
# Epoch [185/200], Loss: 0.0008
# Lote: 0
# Epoch [186/200], Loss: 0.0008
# Lote: 0
# Epoch [187/200], Loss: 0.0008
# Lote: 0
# Epoch [188/200], Loss: 0.0008
# Lote: 0
# Epoch [189/200], Loss: 0.0008
# Lote: 0
# Epoch [190/200], Loss: 0.0008
# Lote: 0
# Epoch [191/200], Loss: 0.0008
# Lote: 0
# Epoch [192/200], Loss: 0.0008
# Lote: 0
# Epoch [193/200], Loss: 0.0008
# Lote: 0
# Epoch [194/200], Loss: 0.0008
# Lote: 0
# Epoch [195/200], Loss: 0.0008
# Lote: 0
# Epoch [196/200], Loss: 0.0008
# Lote: 0
# Epoch [197/200], Loss: 0.0008
# Lote: 0
# Epoch [198/200], Loss: 0.0008
# Lote: 0
# Epoch [199/200], Loss: 0.0008
# Lote: 0
# Epoch [200/200], Loss: 0.0008

# %%
it = iter(ds_loader)
img, label = next(it)

model.eval()

ret = model(img.to(device))
plt.imshow(ret[1][0].detach().cpu().numpy())
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_11196\2660411871.py:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_11196\2660411871.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mask = torch.tensor(mask, dtype=torch.float32)

# %%
# Threshold the output
ret = torch.round(ret)

# Show a matrix of images of 4x2 
for i in range(4):
    # Size image
    plt.figure(figsize=(20, 20))
    plt.subplot(4, 2, 2*i+1)
    plt.imshow(img[i].permute(1, 2, 0).detach().cpu().numpy())
    plt.subplot(4, 2, 2*i+2)
    plt.imshow(ret[i][0].detach().cpu().numpy())

# %%
torch.save(model.state_dict(), "model_unet_coins.pth")

# %%
#model = build_unet()
model.load_state_dict(torch.load("model_unet_coins.pth"))
# Out:
# <All keys matched successfully>

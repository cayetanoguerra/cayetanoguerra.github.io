# %% [markdown]
# # Simulated annealing
#
# Mediante esta técnica de búsqueda heurística intentaremos aproximarnos al mínimo de la siguiente función:
#
# $$
# f(x,y) = 0.2 + x^2 + y^2 - 0.1 \cdot \cos(6 \pi x) - 0.1 \cdot \cos(6 \pi y)
# $$
#
# <img src="imgs/function_min.jpg" width=70%>
#
# Su mínimo se encuentra en el punto $(0,0)$.

# %%
from numpy import asarray, exp
from numpy.random import randn, rand, seed
from matplotlib import pyplot
import math


# define objective function
def objective(step):
    x1 = step[0]
    x2 = step[1]
    obj = 0.2 + x1**2 + x2**2 - 0.1*math.cos(6.0*3.1415*x1) - 0.1*math.cos(6.0*3.1415*x2)
    return obj


# Define simulated annealing algorithm
def sa(objective, area, iterations, step_size, temperature):
    # create initial point
    start_point = area[:, 0] + rand( len( area ) ) * ( area[:, 1] - area[:, 0] )
    
    # evaluate initial point
    start_point_eval = objective(start_point)
    
    # Assign previous and new solution to previous and new_point_eval variable 
    mia_start_point, mia_start_eval = start_point, start_point_eval
    outputs = []
    
    for i in range(iterations):
        
        # First step by mia
        mia_step = mia_start_point + randn( len( area ) ) * step_size  
        mia_step_eval = objective(mia_step)
        
        if mia_step_eval < start_point_eval:
            start_point, start_point_eval = mia_step, mia_step_eval
            outputs.append(start_point_eval)  #Append the new values into the output list
            #print('Acceptance Criteria = %.5f' % mac," ",'iteration Number = ',i," ", 'best_so_far = ',start_point," " ,'new_best = %.5f' % start_point_eval)
            print('iteration Number = ',i," ", 'best_so_far = ',start_point," " ,'new_best = %.5f' % start_point_eval)
          
        difference = mia_start_eval - mia_step_eval
        t = temperature / float(i + 1)
        
        # calculate Metropolis Acceptance Criterion / Acceptance Probability
        mac = exp(difference / t)
        
        # check whether the new point is acceptable 
        if difference > 0 or rand() < mac:
            mia_start_point, mia_start_eval = mia_step, mia_step_eval
            
    return [start_point, start_point_eval, outputs]

seed(1)

# define the area of the search space
# area = asarray([[-6.0, 6.0]])
area = asarray([[-50.0, 50.0],[-50.0, 50.0]])

# initial temperature
temperature = 12

# define the total no. of iterations
iterations = 1200

# define maximum step_size
step_size = 0.1

# perform the simulated annealing search
start_point, output, outputs = sa(objective, area, iterations, step_size, temperature)

#plotting the values
pyplot.plot(outputs, 'ro-')
pyplot.xlabel('Improvement Value')
pyplot.ylabel('Evaluation of Objective Function')
pyplot.show()
# Out:
# iteration Number =  0   best_so_far =  [-8.3506167  21.92515248]   new_best = 550.53550
# iteration Number =  1   best_so_far =  [-8.26407594 21.69499861]   new_best = 539.05545
# iteration Number =  2   best_so_far =  [-8.08959477 21.61887792]   new_best = 532.96760
# iteration Number =  3   best_so_far =  [-8.05769086 21.59394088]   new_best = 531.35911
# iteration Number =  4   best_so_far =  [-7.91148006 21.38792681]   new_best = 520.19255
# iteration Number =  5   best_so_far =  [-7.94372178 21.34952138]   new_best = 518.96062
# iteration Number =  6   best_so_far =  [-7.83034484 21.23953225]   new_best = 512.75261
# iteration Number =  7   best_so_far =  [-7.84758766 21.15174641]   new_best = 509.37327
# iteration Number =  9   best_so_far =  [-7.73339341 21.03878689]   new_best = 502.52951
# iteration Number =  11   best_so_far =  [-7.74568243 20.94520995]   new_best = 498.83862
# iteration Number =  15   best_so_far =  [-7.71811063 20.83614246]   new_best = 493.95707
# iteration Number =  18   best_so_far =  [-7.51390775 20.88089453]   new_best = 492.83059
# iteration Number =  19   best_so_far =  [-7.44556933 20.88318313]   new_best = 491.85525
# iteration Number =  20   best_so_far =  [-7.3598459  20.90157619]   new_best = 491.18443
# iteration Number =  32   best_so_far =  [-7.38207871 20.88150038]   new_best = 490.73359
# iteration Number =  36   best_so_far =  [-7.3238862  20.84047963]   new_best = 488.16580
# iteration Number =  38   best_so_far =  [-7.36141469 20.77660659]   new_best = 486.01835
# iteration Number =  39   best_so_far =  [-7.31906526 20.78434059]   new_best = 485.72061
# iteration Number =  41   best_so_far =  [-7.25058161 20.72479456]   new_best = 482.24058
# iteration Number =  42   best_so_far =  [-7.15067648 20.69397749]   new_best = 479.58065
# iteration Number =  44   best_so_far =  [-7.07662084 20.59860743]   new_best = 474.54089
# iteration Number =  47   best_so_far =  [-7.01862662 20.51591729]   new_best = 470.36581
# iteration Number =  48   best_so_far =  [-6.98357203 20.38468895]   new_best = 464.35307
# iteration Number =  49   best_so_far =  [-6.98744158 20.22311171]   new_best = 457.95099
# iteration Number =  51   best_so_far =  [-6.62913697 20.2323894 ]   new_best = 453.45292
# iteration Number =  55   best_so_far =  [-6.647229   20.17199733]   new_best = 451.30150
# iteration Number =  57   best_so_far =  [-6.65661671 20.15501993]   new_best = 450.73458
# iteration Number =  59   best_so_far =  [-6.57643061 20.15967666]   new_best = 449.97432
# iteration Number =  60   best_so_far =  [-6.59508758 20.14950207]   new_best = 449.77045
# iteration Number =  62   best_so_far =  [-6.53571507 20.0144463 ]   new_best = 443.47543
# iteration Number =  63   best_so_far =  [-6.4526586  20.02576811]   new_best = 442.84172
# iteration Number =  67   best_so_far =  [-6.46630307 20.01386269]   new_best = 442.55117
# iteration Number =  68   best_so_far =  [-6.46456213 19.90166081]   new_best = 438.17392
# iteration Number =  69   best_so_far =  [-6.51627158 19.80195813]   new_best = 434.95718
# iteration Number =  70   best_so_far =  [-6.49139166 19.77229402]   new_best = 433.42020
# iteration Number =  71   best_so_far =  [-6.44187053 19.7548237 ]   new_best = 432.00416
# iteration Number =  72   best_so_far =  [-6.34323701 19.77617709]   new_best = 431.48190
# iteration Number =  73   best_so_far =  [-6.12416704 19.586541  ]   new_best = 421.40240
# iteration Number =  76   best_so_far =  [-5.99102133 19.55781021]   new_best = 418.54900
# iteration Number =  77   best_so_far =  [-5.92301434 19.52583005]   new_best = 416.61741
# iteration Number =  86   best_so_far =  [-5.63392069 19.46560405]   new_best = 410.84849
# iteration Number =  87   best_so_far =  [-5.84959122 19.37573729]   new_best = 409.86186
# iteration Number =  88   best_so_far =  [-6.020265   19.22122959]   new_best = 405.85886
# iteration Number =  89   best_so_far =  [-5.91952574 19.07033802]   new_best = 398.88824
# iteration Number =  90   best_so_far =  [-5.87844865 19.06429068]   new_best = 398.23343
# iteration Number =  92   best_so_far =  [-5.76701035 19.00563829]   new_best = 394.60437
# iteration Number =  97   best_so_far =  [-5.65989281 19.03602859]   new_best = 394.42715
# iteration Number =  99   best_so_far =  [-5.61243009 18.98757229]   new_best = 392.07838
# iteration Number =  101   best_so_far =  [-5.62447655 18.86426021]   new_best = 387.70932
# iteration Number =  102   best_so_far =  [-5.74270836 18.79768476]   new_best = 386.59524
# iteration Number =  105   best_so_far =  [-5.74289751 18.65802272]   new_best = 381.19052
# iteration Number =  108   best_so_far =  [-5.77739623 18.63493875]   new_best = 380.80629
# iteration Number =  111   best_so_far =  [-5.73444361 18.57423891]   new_best = 378.07506
# iteration Number =  112   best_so_far =  [-5.72382134 18.42167087]   new_best = 372.28084
# iteration Number =  113   best_so_far =  [-5.64431873 18.38422704]   new_best = 369.88877
# iteration Number =  117   best_so_far =  [-5.57072175 18.24909085]   new_best = 364.28884
# iteration Number =  118   best_so_far =  [-5.45829921 18.19045053]   new_best = 361.04652
# iteration Number =  119   best_so_far =  [-5.31229947 18.16264275]   new_best = 358.30962
# iteration Number =  120   best_so_far =  [-5.26863819 18.16646491]   new_best = 358.04485
# iteration Number =  122   best_so_far =  [-5.28729609 18.16078246]   new_best = 358.00436
# iteration Number =  123   best_so_far =  [-5.23806244 18.09271465]   new_best = 355.02282
# iteration Number =  124   best_so_far =  [-5.24651324 18.06297846]   new_best = 353.96559
# iteration Number =  126   best_so_far =  [-5.27129966 17.93013599]   new_best = 349.41342
# iteration Number =  127   best_so_far =  [-5.25476334 17.93289043]   new_best = 349.36327
# iteration Number =  128   best_so_far =  [-5.31975372 17.85660919]   new_best = 347.35255
# iteration Number =  129   best_so_far =  [-5.2315172  17.77272697]   new_best = 343.51365
# iteration Number =  131   best_so_far =  [-5.16933685 17.71274652]   new_best = 340.69798
# iteration Number =  132   best_so_far =  [-5.05699564 17.74327322]   new_best = 340.53545
# iteration Number =  133   best_so_far =  [-4.9181177  17.67713879]   new_best = 336.76841
# iteration Number =  136   best_so_far =  [-4.99067741 17.59036193]   new_best = 334.41704
# iteration Number =  137   best_so_far =  [-5.00427514 17.51063495]   new_best = 331.86360
# iteration Number =  138   best_so_far =  [-4.97600757 17.42802521]   new_best = 328.62719
# iteration Number =  140   best_so_far =  [-4.88068118 17.38460113]   new_best = 326.25074
# iteration Number =  141   best_so_far =  [-4.75556977 17.35709629]   new_best = 324.00390
# iteration Number =  145   best_so_far =  [-4.95928989 17.16283737]   new_best = 319.38543
# iteration Number =  146   best_so_far =  [-5.20993396 16.95142098]   new_best = 314.70267
# iteration Number =  148   best_so_far =  [-5.18026154 16.85769226]   new_best = 311.40376
# iteration Number =  149   best_so_far =  [-5.17816041 16.83105856]   new_best = 310.49546
# iteration Number =  150   best_so_far =  [-5.21534192 16.79031783]   new_best = 309.44378
# iteration Number =  153   best_so_far =  [-5.36170163 16.7323201 ]   new_best = 308.79860
# iteration Number =  156   best_so_far =  [-5.33695077 16.56069105]   new_best = 302.88198
# iteration Number =  157   best_so_far =  [-5.27824348 16.53417484]   new_best = 301.46879
# iteration Number =  158   best_so_far =  [-5.37627164 16.33719148]   new_best = 295.83911
# iteration Number =  159   best_so_far =  [-5.30419575 16.33921024]   new_best = 295.11966
# iteration Number =  165   best_so_far =  [-5.2423972 16.3207926]   new_best = 293.96857
# iteration Number =  166   best_so_far =  [-5.25399572 16.30324671]   new_best = 293.50924
# iteration Number =  167   best_so_far =  [-5.34738718 16.24994467]   new_best = 292.75967
# iteration Number =  169   best_so_far =  [-5.28922802 16.15923303]   new_best = 289.32847
# iteration Number =  170   best_so_far =  [-5.24608505 16.00830379]   new_best = 283.89595
# iteration Number =  171   best_so_far =  [-5.29471834 15.99172673]   new_best = 283.79626
# iteration Number =  172   best_so_far =  [-5.22481352 15.87620609]   new_best = 279.66829
# iteration Number =  173   best_so_far =  [-4.86747762 15.82453165]   new_best = 274.48677
# iteration Number =  174   best_so_far =  [-4.8403776 15.6998766]   new_best = 270.13299
# iteration Number =  175   best_so_far =  [-4.80643489 15.7066063 ]   new_best = 270.01302
# iteration Number =  177   best_so_far =  [-5.02068157 15.62358941]   new_best = 269.34301
# iteration Number =  180   best_so_far =  [-4.84465664 15.61752417]   new_best = 267.61616
# iteration Number =  181   best_so_far =  [-5.08600694 15.43976753]   new_best = 264.50004
# iteration Number =  183   best_so_far =  [-5.15205498 15.32520523]   new_best = 261.60304
# iteration Number =  184   best_so_far =  [-4.98913624 15.3404789 ]   new_best = 260.22471
# iteration Number =  186   best_so_far =  [-4.78367383 15.34581986]   new_best = 258.53937
# iteration Number =  188   best_so_far =  [-4.64592283 15.35429955]   new_best = 257.35414
# iteration Number =  190   best_so_far =  [-4.53123279 15.34932929]   new_best = 256.32155
# iteration Number =  194   best_so_far =  [-4.46929831 15.27296008]   new_best = 253.48035
# iteration Number =  195   best_so_far =  [-4.37280958 15.19881466]   new_best = 250.33437
# iteration Number =  196   best_so_far =  [-4.24095045 15.16784767]   new_best = 248.36646
# iteration Number =  197   best_so_far =  [-4.35923434 15.10733752]   new_best = 247.38910
# iteration Number =  200   best_so_far =  [-4.39898182 15.0738643 ]   new_best = 246.72090
# iteration Number =  203   best_so_far =  [-4.4986039  15.00138212]   new_best = 245.47888
# iteration Number =  205   best_so_far =  [-4.41150692 14.95053641]   new_best = 243.11105
# iteration Number =  206   best_so_far =  [-4.333765   14.93865929]   new_best = 242.00555
# iteration Number =  208   best_so_far =  [-4.36543829 14.80178326]   new_best = 238.34983
# iteration Number =  210   best_so_far =  [-4.31389691 14.69029615]   new_best = 234.43064
# iteration Number =  213   best_so_far =  [-4.20988799 14.59845215]   new_best = 231.07941
# iteration Number =  215   best_so_far =  [-4.25221971 14.47426535]   new_best = 227.86987
# iteration Number =  216   best_so_far =  [-4.3008223  14.45112492]   new_best = 227.51026
# iteration Number =  219   best_so_far =  [-4.29930339 14.36986295]   new_best = 225.01927
# iteration Number =  220   best_so_far =  [-4.37808359 14.23844147]   new_best = 222.05655
# iteration Number =  221   best_so_far =  [-4.35822265 14.2113709 ]   new_best = 221.13500
# iteration Number =  222   best_so_far =  [-4.33009794 14.08596883]   new_best = 217.26865
# iteration Number =  223   best_so_far =  [-4.31778543 13.94900885]   new_best = 213.26583
# iteration Number =  225   best_so_far =  [-4.24844881 13.87320212]   new_best = 210.79180
# iteration Number =  232   best_so_far =  [-4.27734854 13.83402049]   new_best = 209.92674
# iteration Number =  233   best_so_far =  [-4.20894841 13.7986795 ]   new_best = 208.46780
# iteration Number =  235   best_so_far =  [-4.12694153 13.64754721]   new_best = 203.46698
# iteration Number =  236   best_so_far =  [-4.17445224 13.45159646]   new_best = 198.73105
# iteration Number =  237   best_so_far =  [-4.04868772 13.43017821]   new_best = 196.92509
# iteration Number =  238   best_so_far =  [-4.23565861 13.34093229]   new_best = 196.04913
# iteration Number =  240   best_so_far =  [-4.1345379  13.19327602]   new_best = 191.52705
# iteration Number =  242   best_so_far =  [-3.92986704 13.13689822]   new_best = 188.28181
# iteration Number =  243   best_so_far =  [-3.94914913 13.03097408]   new_best = 185.46094
# iteration Number =  246   best_so_far =  [-3.93702328 12.95945032]   new_best = 183.53859
# iteration Number =  249   best_so_far =  [-3.87280078 12.96521112]   new_best = 183.29019
# iteration Number =  251   best_so_far =  [-3.72802963 12.98991905]   new_best = 182.69771
# iteration Number =  254   best_so_far =  [-3.61188563 12.98716611]   new_best = 181.76420
# iteration Number =  255   best_so_far =  [-3.43724212 12.90965908]   new_best = 178.72545
# iteration Number =  256   best_so_far =  [-3.42307807 12.65802869]   new_best = 172.05646
# iteration Number =  257   best_so_far =  [-3.48264485 12.62711656]   new_best = 171.79453
# iteration Number =  259   best_so_far =  [-3.33596744 12.63067513]   new_best = 170.68533
# iteration Number =  262   best_so_far =  [-3.36936425 12.51099881]   new_best = 168.09778
# iteration Number =  263   best_so_far =  [-3.42176634 12.36541987]   new_best = 164.73885
# iteration Number =  264   best_so_far =  [-3.32223111 12.33064118]   new_best = 163.08432
# iteration Number =  266   best_so_far =  [-3.51673581 12.23909874]   new_best = 162.47916
# iteration Number =  267   best_so_far =  [-3.39422022 12.13374413]   new_best = 158.98821
# iteration Number =  268   best_so_far =  [-3.31261585 12.07250343]   new_best = 156.80543
# iteration Number =  269   best_so_far =  [-3.27330493 11.89011145]   new_best = 152.29548
# iteration Number =  270   best_so_far =  [-3.15659741 11.88614458]   new_best = 151.59768
# iteration Number =  271   best_so_far =  [-3.06801483 11.90513074]   new_best = 151.33843
# iteration Number =  272   best_so_far =  [-2.98820845 11.89493754]   new_best = 150.56185
# iteration Number =  273   best_so_far =  [-2.9138728  11.74398027]   new_best = 146.60518
# iteration Number =  275   best_so_far =  [-2.84765536 11.73140432]   new_best = 145.99646
# iteration Number =  276   best_so_far =  [-2.73145279 11.6662    ]   new_best = 143.62667
# iteration Number =  277   best_so_far =  [-2.78120581 11.56380746]   new_best = 141.74869
# iteration Number =  278   best_so_far =  [-2.73662845 11.49072154]   new_best = 139.79909
# iteration Number =  281   best_so_far =  [-2.88264806 11.36146858]   new_best = 137.56599
# iteration Number =  282   best_so_far =  [-2.86650361 11.30722172]   new_best = 136.26345
# iteration Number =  284   best_so_far =  [-2.89478997 11.28058903]   new_best = 135.81773
# iteration Number =  285   best_so_far =  [-2.78789281 11.28462617]   new_best = 135.32029
# iteration Number =  286   best_so_far =  [-2.80359217 11.1511059 ]   new_best = 132.58745
# iteration Number =  287   best_so_far =  [-2.81423819 10.87200626]   new_best = 126.48898
# iteration Number =  288   best_so_far =  [-2.85984994 10.77401723]   new_best = 124.58923
# iteration Number =  289   best_so_far =  [-2.79059251 10.72615   ]   new_best = 123.06286
# iteration Number =  291   best_so_far =  [-2.78741558 10.60898636]   new_best = 120.53901
# iteration Number =  292   best_so_far =  [-2.71127559 10.56599899]   new_best = 119.15721
# iteration Number =  294   best_so_far =  [-2.67946017 10.56407583]   new_best = 118.91812
# iteration Number =  297   best_so_far =  [-2.48748094 10.42490644]   new_best = 115.17833
# iteration Number =  299   best_so_far =  [-2.521876   10.29110417]   new_best = 112.48881
# iteration Number =  300   best_so_far =  [-2.49535027 10.20691984]   new_best = 110.78055
# iteration Number =  301   best_so_far =  [-2.48010589 10.17403978]   new_best = 110.05412
# iteration Number =  304   best_so_far =  [-2.17367643 10.02960702]   new_best = 105.53191
# iteration Number =  305   best_so_far =  [-2.16676783 10.00702212]   new_best = 105.03618
# iteration Number =  306   best_so_far =  [-2.28816224  9.94007307]   new_best = 104.13274
# iteration Number =  307   best_so_far =  [-2.48770393  9.82782312]   new_best = 103.17148
# iteration Number =  308   best_so_far =  [-2.44782409  9.82531039]   new_best = 102.88264
# iteration Number =  309   best_so_far =  [-2.32222481  9.76323537]   new_best = 100.83987
# iteration Number =  310   best_so_far =  [-2.22481453  9.77644456]   new_best = 100.82182
# iteration Number =  311   best_so_far =  [-2.35187449  9.70402398]   new_best = 99.72883
# iteration Number =  314   best_so_far =  [-2.3057316   9.59143848]   new_best = 97.41069
# iteration Number =  315   best_so_far =  [-2.12619474  9.54995746]   new_best = 96.05387
# iteration Number =  317   best_so_far =  [-2.16414649  9.4484771 ]   new_best = 94.31313
# iteration Number =  318   best_so_far =  [-2.12054787  9.37972836]   new_best = 92.67594
# iteration Number =  319   best_so_far =  [-2.39038404  9.25839454]   new_best = 91.56890
# iteration Number =  321   best_so_far =  [-2.41960847  9.24261373]   new_best = 91.50021
# iteration Number =  323   best_so_far =  [-2.36649209  9.24301381]   new_best = 91.16606
# iteration Number =  324   best_so_far =  [-2.3343655   9.17049232]   new_best = 89.74698
# iteration Number =  325   best_so_far =  [-2.18071187  9.17045482]   new_best = 89.24907
# iteration Number =  326   best_so_far =  [-2.05135691  9.12655505]   new_best = 87.71769
# iteration Number =  327   best_so_far =  [-1.99235296  9.05861667]   new_best = 86.08369
# iteration Number =  328   best_so_far =  [-2.08744389  8.98818164]   new_best = 85.25504
# iteration Number =  329   best_so_far =  [-2.09203055  8.96630829]   new_best = 84.90728
# iteration Number =  330   best_so_far =  [-1.93810985  8.85143787]   new_best = 82.35939
# iteration Number =  332   best_so_far =  [-1.92231131  8.85329197]   new_best = 82.35873
# iteration Number =  335   best_so_far =  [-1.61643309  8.77278951]   new_best = 79.75755
# iteration Number =  337   best_so_far =  [-1.70218277  8.67937132]   new_best = 78.25318
# iteration Number =  338   best_so_far =  [-1.64791824  8.48355441]   new_best = 74.88763
# iteration Number =  339   best_so_far =  [-1.58013749  8.37289711]   new_best = 72.73458
# iteration Number =  343   best_so_far =  [-1.51312547  8.17605169]   new_best = 69.53286
# iteration Number =  345   best_so_far =  [-1.44057041  8.14363127]   new_best = 68.72798
# iteration Number =  347   best_so_far =  [-1.45731189  8.13718726]   new_best = 68.69157
# iteration Number =  350   best_so_far =  [-1.48532069  8.10382276]   new_best = 68.21155
# iteration Number =  351   best_so_far =  [-1.52615758  8.08883243]   new_best = 68.05640
# iteration Number =  353   best_so_far =  [-1.41089766  8.06640885]   new_best = 67.21486
# iteration Number =  356   best_so_far =  [-1.42311306  7.99832369]   new_best = 66.11054
# iteration Number =  360   best_so_far =  [-1.34910334  7.9694642 ]   new_best = 65.35316
# iteration Number =  364   best_so_far =  [-1.28918202  7.82244049]   new_best = 63.08311
# iteration Number =  366   best_so_far =  [-1.21868881  7.78367981]   new_best = 62.38554
# iteration Number =  367   best_so_far =  [-1.28745334  7.77131301]   new_best = 62.22472
# iteration Number =  371   best_so_far =  [-1.22598071  7.73641459]   new_best = 61.57320
# iteration Number =  374   best_so_far =  [-1.19941647  7.71036799]   new_best = 61.10169
# iteration Number =  378   best_so_far =  [-1.1403603   7.68608067]   new_best = 60.57065
# iteration Number =  381   best_so_far =  [-1.10326901  7.62288643]   new_best = 59.49472
# iteration Number =  383   best_so_far =  [-1.06340917  7.60368606]   new_best = 59.07311
# iteration Number =  385   best_so_far =  [-1.15267467  7.49555506]   new_best = 57.90814
# iteration Number =  386   best_so_far =  [-1.28626767  7.42846088]   new_best = 56.99506
# iteration Number =  389   best_so_far =  [-1.56519694  7.33448481]   new_best = 56.37813
# iteration Number =  392   best_so_far =  [-1.52077883  7.27504222]   new_best = 55.48636
# iteration Number =  394   best_so_far =  [-1.5602478   7.15786088]   new_best = 54.01014
# iteration Number =  395   best_so_far =  [-1.46184657  7.10189274]   new_best = 52.88296
# iteration Number =  397   best_so_far =  [-1.58042234  7.05286208]   new_best = 52.39151
# iteration Number =  404   best_so_far =  [-1.48387086  7.06009467]   new_best = 52.29943
# iteration Number =  405   best_so_far =  [-1.40948801  7.02099162]   new_best = 51.37499
# iteration Number =  410   best_so_far =  [-1.36497644  7.03350122]   new_best = 51.36958
# iteration Number =  413   best_so_far =  [-1.45515744  7.00244294]   new_best = 51.31807
# iteration Number =  415   best_so_far =  [-1.53915633  6.77262235]   new_best = 48.55247
# iteration Number =  416   best_so_far =  [-1.39350359  6.80428607]   new_best = 48.48299
# iteration Number =  419   best_so_far =  [-1.37598682  6.7989377 ]   new_best = 48.32894
# iteration Number =  420   best_so_far =  [-1.39429301  6.77683481]   new_best = 48.07666
# iteration Number =  422   best_so_far =  [-1.43023509  6.73385981]   new_best = 47.58535
# iteration Number =  426   best_so_far =  [-1.37943666  6.70145658]   new_best = 46.86827
# iteration Number =  427   best_so_far =  [-1.53054432  6.61431438]   new_best = 46.32082
# iteration Number =  430   best_so_far =  [-1.46575184  6.47914944]   new_best = 44.49987
# iteration Number =  433   best_so_far =  [-1.40987154  6.32866031]   new_best = 42.12725
# iteration Number =  434   best_so_far =  [-1.60426372  6.21125794]   new_best = 41.38200
# iteration Number =  435   best_so_far =  [-1.63998247  6.1591203 ]   new_best = 40.83568
# iteration Number =  436   best_so_far =  [-1.66299388  6.11001886]   new_best = 40.24603
# iteration Number =  439   best_so_far =  [-1.62422041  6.07453898]   new_best = 39.65168
# iteration Number =  440   best_so_far =  [-1.50651518  6.0104282 ]   new_best = 38.59595
# iteration Number =  441   best_so_far =  [-1.37424579  6.0298457 ]   new_best = 38.29106
# iteration Number =  442   best_so_far =  [-1.11770051  5.98343421]   new_best = 37.21597
# iteration Number =  444   best_so_far =  [-0.99005003  5.81942493]   new_best = 35.04417
# iteration Number =  448   best_so_far =  [-1.18762304  5.76053182]   new_best = 34.90591
# iteration Number =  450   best_so_far =  [-1.00271769  5.79923204]   new_best = 34.81651
# iteration Number =  451   best_so_far =  [-1.05494759  5.72590008]   new_best = 34.00364
# iteration Number =  452   best_so_far =  [-0.98268491  5.60728373]   new_best = 32.46925
# iteration Number =  457   best_so_far =  [-0.85719525  5.44983402]   new_best = 30.78383
# iteration Number =  459   best_so_far =  [-0.69400166  5.40965514]   new_best = 29.84550
# iteration Number =  463   best_so_far =  [-0.65397595  5.38834626]   new_best = 29.51368
# iteration Number =  466   best_so_far =  [-0.78231032  5.31204657]   new_best = 28.99508
# iteration Number =  468   best_so_far =  [-0.95976992  5.2808236 ]   new_best = 28.88105
# iteration Number =  470   best_so_far =  [-1.07918061  5.17182753]   new_best = 28.20411
# iteration Number =  471   best_so_far =  [-1.01611152  5.17511475]   new_best = 28.01763
# iteration Number =  474   best_so_far =  [-1.08055049  5.14913175]   new_best = 27.97034
# iteration Number =  475   best_so_far =  [-1.06905623  5.01425183]   new_best = 26.36247
# iteration Number =  476   best_so_far =  [-0.93659525  4.97772982]   new_best = 25.72716
# iteration Number =  477   best_so_far =  [-0.97170833  4.96292604]   new_best = 25.61238
# iteration Number =  478   best_so_far =  [-1.06666016  4.82698593]   new_best = 24.70584
# iteration Number =  480   best_so_far =  [-0.84318799  4.83167055]   new_best = 24.45424
# iteration Number =  481   best_so_far =  [-0.81410919  4.7878651 ]   new_best = 23.94518
# iteration Number =  483   best_so_far =  [-0.9135675   4.57873979]   new_best = 22.01425
# iteration Number =  484   best_so_far =  [-0.93424041  4.54870086]   new_best = 21.79195
# iteration Number =  486   best_so_far =  [-1.0324565   4.50397004]   new_best = 21.56956
# iteration Number =  488   best_so_far =  [-0.97078414  4.40621118]   new_best = 20.45211
# iteration Number =  491   best_so_far =  [-0.97135518  4.37768311]   new_best = 20.15467
# iteration Number =  494   best_so_far =  [-0.74147303  4.37099413]   new_best = 19.76333
# iteration Number =  495   best_so_far =  [-0.87526049  4.27889063]   new_best = 19.29378
# iteration Number =  498   best_so_far =  [-0.82056169  4.27816252]   new_best = 19.22268
# iteration Number =  500   best_so_far =  [-0.7842269  4.1801905]   new_best = 18.44593
# iteration Number =  502   best_so_far =  [-1.10243979  4.11377168]   new_best = 18.42776
# iteration Number =  504   best_so_far =  [-1.0244906   4.00514159]   new_best = 17.10163
# iteration Number =  511   best_so_far =  [-1.11583495  3.94275108]   new_best = 17.00081
# iteration Number =  512   best_so_far =  [-1.0896474   3.88404818]   new_best = 16.54283
# iteration Number =  513   best_so_far =  [-1.00202741  3.89637372]   new_best = 16.32338
# iteration Number =  517   best_so_far =  [-0.78599313  3.72388326]   new_best = 14.70037
# iteration Number =  518   best_so_far =  [-0.59047207  3.73012735]   new_best = 14.41234
# iteration Number =  520   best_so_far =  [-0.45918253  3.73246306]   new_best = 14.38129
# iteration Number =  521   best_so_far =  [-0.54229987  3.67606441]   new_best = 13.97895
# iteration Number =  522   best_so_far =  [-0.48950481  3.51995242]   new_best = 13.02081
# iteration Number =  523   best_so_far =  [-0.46866952  3.44711741]   new_best = 12.43945
# iteration Number =  524   best_so_far =  [-0.39684788  3.37250004]   new_best = 11.62064
# iteration Number =  526   best_so_far =  [-0.37518482  3.30052414]   new_best = 11.08237
# iteration Number =  530   best_so_far =  [-0.4749469   3.18655413]   new_best = 10.76187
# iteration Number =  532   best_so_far =  [-0.39139661  3.10952905]   new_best = 10.02373
# iteration Number =  533   best_so_far =  [-0.17967359  3.07729221]   new_best = 9.78749
# iteration Number =  535   best_so_far =  [-0.09811355  3.04909162]   new_best = 9.47379
# iteration Number =  537   best_so_far =  [-0.05143327  2.94608257]   new_best = 8.77296
# iteration Number =  538   best_so_far =  [-0.05259421  2.94322914]   new_best = 8.76275
# iteration Number =  539   best_so_far =  [0.04515167 2.78263832]   new_best = 7.93678
# iteration Number =  547   best_so_far =  [0.07846312 2.57938434]   new_best = 6.85779
# iteration Number =  549   best_so_far =  [-0.07579598  2.53456899]   new_best = 6.69522
# iteration Number =  550   best_so_far =  [-0.05950521  2.50156305]   new_best = 6.51790
# iteration Number =  551   best_so_far =  [0.05078633 2.3521888 ]   new_best = 5.58400
# iteration Number =  552   best_so_far =  [0.13016362 2.22504942]   new_best = 5.29046
# iteration Number =  553   best_so_far =  [-0.01400043  2.13451417]   new_best = 4.74193
# iteration Number =  559   best_so_far =  [0.01778535 2.09184744]   new_best = 4.49757
# iteration Number =  566   best_so_far =  [-0.06319921  1.97534236]   new_best = 3.97958
# iteration Number =  567   best_so_far =  [-0.14276187  1.90433711]   new_best = 3.96003
# iteration Number =  573   best_so_far =  [-0.22840197  1.80360216]   new_best = 3.62941
# iteration Number =  579   best_so_far =  [-0.13803103  1.74718577]   new_best = 3.35209
# iteration Number =  580   best_so_far =  [-0.08730587  1.73552903]   new_best = 3.20013
# iteration Number =  581   best_so_far =  [-0.0569469   1.65545032]   new_best = 2.79829
# iteration Number =  586   best_so_far =  [-0.11257369  1.39538614]   new_best = 2.17302
# iteration Number =  587   best_so_far =  [0.15862129 1.28557128]   new_best = 1.91462
# iteration Number =  589   best_so_far =  [0.26665141 1.30086831]   new_best = 1.85069
# iteration Number =  592   best_so_far =  [0.30176356 1.29504273]   new_best = 1.81038
# iteration Number =  593   best_so_far =  [0.22230711 1.17602892]   new_best = 1.78079
# iteration Number =  594   best_so_far =  [0.08815387 1.1150409 ]   new_best = 1.51638
# iteration Number =  595   best_so_far =  [0.19188784 1.02609608]   new_best = 1.29044
# iteration Number =  599   best_so_far =  [0.2693413  0.90237961]   new_best = 1.07785
# iteration Number =  603   best_so_far =  [0.28256086 0.80794782]   new_best = 0.96379
# iteration Number =  604   best_so_far =  [0.2996984  0.72223398]   new_best = 0.68087
# iteration Number =  605   best_so_far =  [0.37642468 0.59543047]   new_best = 0.60486
# iteration Number =  609   best_so_far =  [0.2861415 0.6535814]   new_best = 0.54912
# iteration Number =  614   best_so_far =  [0.20198457 0.33824565]   new_best = 0.33429
# iteration Number =  618   best_so_far =  [0.22800877 0.34381885]   new_best = 0.31243
# iteration Number =  621   best_so_far =  [0.26276226 0.35817897]   new_best = 0.28428
# iteration Number =  622   best_so_far =  [0.31863132 0.3036825 ]   new_best = 0.21279
# iteration Number =  685   best_so_far =  [-0.0469331  0.3713309]   new_best = 0.20129
# iteration Number =  690   best_so_far =  [-0.00266934  0.27078195]   new_best = 0.13529
# iteration Number =  695   best_so_far =  [-0.00990808 -0.003137  ]   new_best = 0.00202
# iteration Number =  846   best_so_far =  [0.00699183 0.00591782]   new_best = 0.00157
# iteration Number =  867   best_so_far =  [-0.00800224  0.00024342]   new_best = 0.00120
# iteration Number =  903   best_so_far =  [-0.00477556 -0.00168133]   new_best = 0.00048

# %% [markdown]
# ## Ejercicios
#
# 1) Crea un código para generar 1200 muestras aleatorias (mismo número de iteraciones que el código anterior) y compara el mejor valor obtenido de forma totalmente aleatoria con el mejor valor obtenido mediante *simulated annealing*
#
# 2) Qué ocurriría si la temperatura se mantuviera inalterada durante todas las iteraciones?
